# %%
# Complete Python Pandas Project - Full Executable Code

import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import warnings
warnings.filterwarnings('ignore')

# ==================== SETUP DATA ====================
print("="*80)
print("COMPLETE PANDAS TUTORIAL PROJECT - OLYMPICS & COFFEE SALES ANALYSIS")
print("="*80)

# 1. COFFEE SALES DATA
coffee_data = {
    'day': ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'],
    'coffee_type': ['Latte', 'Espresso', 'Cappuccino', 'Latte', 'Espresso', 'Cappuccino', 'Latte'],
    'units_sold': [25, 18, 22, 30, 15, 35, 28],
    'revenue': [124.75, 71.82, 99.0, 149.7, 59.85, 157.5, 139.72]
}

# 2. OLYMPIC ATHLETES DATA
np.random.seed(42)
sports = ['Basketball', 'Swimming', 'Track and Field', 'Gymnastics', 'Volleyball']
countries = ['USA', 'China', 'India', 'Japan', 'Brazil', 'Russia', 'Germany']
cities = ['New York', 'Beijing', 'Mumbai', 'Tokyo', 'Rio', 'Moscow', 'Berlin']

athletes_data = {
    'athlete_id': range(1, 51),
    'name': [f'Athlete_{i}' for i in range(1, 51)],
    'height_cm': np.random.randint(160, 210, 50),
    'weight_kg': np.random.randint(50, 120, 50),
    'sport': np.random.choice(sports, 50),
    'born_country': np.random.choice(countries, 50),
    'born_city': np.random.choice(cities, 50),
    'born_date': pd.date_range(start='1990-01-01', periods=50, freq='D'),
    'medals': np.random.randint(0, 5, 50)
}

# 3. OLYMPIC RESULTS DATA
results_data = {
    'athlete_id': np.random.choice(range(1, 51), 100),
    'event': np.random.choice(['100m', '200m', '400m', 'Backstroke', 'Breaststroke', 'Vault', 'Floor'], 100),
    'medal': np.random.choice([None, 'Gold', 'Silver', 'Bronze'], 100),
    'year': np.random.choice([2012, 2016, 2020, 2024], 100)
}

# Create DataFrames
df_coffee = pd.DataFrame(coffee_data)
df_athletes = pd.DataFrame(athletes_data)
df_results = pd.DataFrame(results_data)

# ====
# Out:
# ...
# COMPLETE PANDAS TUTORIAL PROJECT - OLYMPICS & COFFEE SALES ANALYSIS
# ...
